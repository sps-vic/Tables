# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import *
plt.figure(figsize=(16,8))

# Statisticss
y = np.array([[0.02, 0.022, 0.039, 0.045, 0.051, 0.24, 0.559, 0.716, 0.802, 1.806, 1.91]])
sfrratio = np.array([2.10E-13, 2.12E-11, 9.98E-13, 3.28E-13, 7.91E-14, 2.49E-12, 2.71E-11,
                    7.98E-11, 2.83E-11, 5.57E-11, 1.67E-11])

plotting_value = sorted(sfrratio)
average_sfrratio = sum(sfrratio)/len(sfrratio)
average_sfr = sum(y)/len(y)
s = 500

# Plotting
plt.scatter(y, sfrratio, s, alpha=0.5, marker=r'*', color = 'indigo')
plt.plot([1e-11, 1e-11, 1e-11, 1e-11, 1e-11, 1e-11,1e-11,1e-11,1e-11,1e-11],color = 'k', lw=1.8, ls='--',
        label='Threshold')
plt.plot([1.94e-11, 1.94e-11, 1.94e-11, 1.94e-11],color = 'pink', lw=1.8, ls='--', label='Average SFR/Mass Ratio')

# Labels
plt.xlim((0, 2))
plt.legend(loc='upper left', fontsize = 15)
plt.rc('xtick',labelsize=10)
plt.rc('ytick',labelsize=10)
plt.xlabel("Star Formation Rates", fontsize = 18)
plt.ylabel("SFR/Mass Ratio (per year)", fontsize = 18)
tick_params(width=3, length=5, direction = 'in')
plt.show()
